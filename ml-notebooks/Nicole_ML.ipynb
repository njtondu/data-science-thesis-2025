# %% [markdown]
# # Modelo de Regresion

# %% [markdown]
# ### Notebook Set Up

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.multioutput import MultiOutputRegressor
from sklearn.metrics import mean_absolute_error, r2_score
import matplotlib.pyplot as plt

# %%
import os

# Muestra la ruta actual de tu notebook
os.getcwd()
# Out:
# '/Users/nicoletondu/Desktop/data-science-thesis-2025'

# %% [markdown]
# ### Read the data

# %%
import pandas as pd

# Paths correctos desde tu working directory actual
path_2023 = "data/raw-data/eda_data/station_passenger_counts_2023.csv"
path_2024_2025 = "data/raw-data/eda_data/station_passenger_counts_2024_2025.csv"

# Lectura de los dos CSV
df_2023 = pd.read_csv(path_2023)
df_2024_2025 = pd.read_csv(path_2024_2025)

# Unimos ambos en un solo DataFrame
df_passengers = pd.concat([df_2023, df_2024_2025], ignore_index=True)

# Chequeo rápido
print("Shape:", df_passengers.shape)
df_passengers.head()
# Out:
# Shape: (411626, 5)
#    TravelDate DayOfWeek          Station  EntryTapCount  ExitTapCount
# 0    20230101    Sunday   Abbey Road DLR            360           322
# 1    20230101    Sunday       Abbey Wood           4375          4382
# 2    20230101    Sunday    Acton Central            779           709
# 3    20230101    Sunday  Acton Main Line           1087           967
# 4    20230101    Sunday       Acton Town           2608          3059

# %%
# Path relativo para la tabla de estaciones
stations_path = "data/processed/stations_dimension_table.csv"

# Lectura de la tabla de estaciones
df_stations = pd.read_csv(stations_path)

# Chequeo rápido
print("Shape:", df_stations.shape)
df_stations.head()
# Out:
# Shape: (946, 15)
#   StopAreaNaptanCode            Mode           Line     UniqueId  \
# 0           910GABWD    nationalRail  national-rail          NaN
# 1           910GABWD  elizabeth-line      elizabeth          NaN
# 2        910GACTNCTL      overground        mildmay  910GACTNCTL
# 3        910GACTONML  elizabeth-line      elizabeth  910GACTONML
# 4        910GANERLEY      overground       windrush  910GANERLEY
#
#               Name FareZones HubNaptanCode   Wifi  AirportInterchange  \
# 0              NaN       NaN           NaN    NaN                 NaN
# 1              NaN       NaN           NaN    NaN                 NaN
# 2    Acton Central         3           NaN   True                 NaN
# 3  Acton Main Line         3           NaN  False                 NaN
# 4          Anerley         4           NaN   True                 NaN
#
#   BlueBadgeCarParking  BlueBadgeCarParkSpaces StationUniqueId IsAccessible  \
# 0                 NaN                     NaN             NaN          NaN
# 1                 NaN                     NaN             NaN          NaN
# 2               False                     NaN             NaN          NaN
# 3               False                     NaN     910GACTONML         True
# 4               False                     NaN             NaN          NaN
#
#   IsFeeCharged   Id
# 0          NaN  NaN
# 1          NaN  NaN
# 2          NaN  NaN
# 3        False  1.0
# 4          NaN  NaN
